# %%
import pandas as pd

# %%
df1 = pd.read_csv('Data\chunk_1 - chunk_1.csv')
df2 = pd.read_csv('Data\chunk_2 - chunk_2.csv')
df3 = pd.read_csv('Data\chunk_3 - chunk_3.csv')
df4 = pd.read_csv('Data\chunk_4 - chunk_4.csv')
df5 = pd.read_csv('Data\chunk_5 - chunk_5.csv')
df6 = pd.read_csv('Data\chunk_6 - chunk_6.csv')
df7 = pd.read_csv('Data\chunk_7 - chunk_7.csv')
df8 = pd.read_csv('Data\chunk_8 - chunk_8.csv')
df9 = pd.read_csv('Data\chunk_9 - chunk_9.csv')
df10 = pd.read_csv('Data\chunk_10 - chunk_10.csv')
df11 = pd.read_csv('Data\chunk_11 - chunk_11.csv')
df12 = pd.read_csv('Data\chunk_12 - chunk_12.csv')

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'course_id', 'url', 'title', 'translated_title',
#        'language_checker', 'is_paid', 'instructors', 'translated_instructors',
#        'image_480x270', 'published_title', 'headline', 'translated_headline',
#        'num_subscribers', 'avg_rating', 'avg_rating_recent', 'rating',
#        'num_reviews', 'num_published_lectures', 'num_published_practice_tests',
#        'has_closed_caption', 'created_at', 'instructional_level',
#        'published_at', 'objectives_summary', 'translated_objectives_summary',
#        'is_recently_published', 'last_update_date', 'content_info', 'category',
#        'char_count', 'description', 'preprocessed_description_stemmed',
#        'preprocessed_description_unstemmed'],
#       dtype='object')

# %%
df3.rename(columns={'languege_checker': 'language_checker'}, inplace=True)

# %%
# Out:
# Index(['Unnamed: 0', 'course_id', 'url', 'title', 'translated_title',
#        'language_checker', 'is_paid', 'instructors', 'translated_instructors',
#        'image_480x270', 'published_title', 'headline', 'translated_headline',
#        'num_subscribers', 'avg_rating', 'avg_rating_recent', 'rating',
#        'num_reviews', 'num_published_lectures', 'num_published_practice_tests',
#        'has_closed_caption', 'created_at', 'instructional_level',
#        'published_at', 'objectives_summary', 'translated_objectives_summary',
#        'is_recently_published', 'last_update_date', 'content_info', 'category',
#        'char_count', 'description', 'preprocessed_description_stemmed',
#        'preprocessed_description_unstemmed'],
#       dtype='object')

# %%
# Concatenating the DataFrames
all_data = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12], ignore_index=True)

# Display the concatenated DataFrame
print(all_data)
# Out:
#         Unnamed: 0  course_id  \
# 0                0     655608
# 1                1     591930
# 2                2    1080376
# 3                3    2108272
# 4                4    1336872
# ...            ...        ...
# 111013      111042    4330136
# 111014      111043    1465960
# 111015      111044    4545956
# 111016      111045    4409526
# 111017      111046    4560412
#
#                                                       url  \
# 0               /course/productivity-and-time-management/
# 1       /course/become-a-superlearner-2-speed-reading-...
# 2       /course/life-coaching-online-certification-cou...
# 3                            /course/do-more-stress-less/
# 4       /course/nlp-practitioner-neuro-linguistic-prog...
# ...                                                   ...
# 111013                             /course/gimp-dinosaur/
# 111014  /course/gopro-prise-en-main-materiel-et-logici...
# 111015         /course/video-bearbeitung-mit-type-studio/
# ...

# %%
final_dataframe = all_data[all_data['language_checker'] == 'en']

# %%
final_dataframe
# Out:
#         Unnamed: 0  course_id  \
# 0                0     655608
# 1                1     591930
# 2                2    1080376
# 3                3    2108272
# 4                4    1336872
# ...            ...        ...
# 110987      111016    3964184
# 110995      111024    4381456
# 111000      111029    4538952
# 111008      111037    4479522
# 111009      111038    2329094
#
#                                                       url  \
# 0               /course/productivity-and-time-management/
# 1       /course/become-a-superlearner-2-speed-reading-...
# 2       /course/life-coaching-online-certification-cou...
# 3                            /course/do-more-stress-less/
# 4       /course/nlp-practitioner-neuro-linguistic-prog...
# ...                                                   ...
# 110987  /course/learn-basic-video-editing-in-adobe-pre...
# 110995                /course/learn-video-editing-course/
# 111000    /course/learna-adobe-premiere-pro-from-scratch/
# ...

# %%
final_dataframe.to_csv('Data/final_dataframe.csv')

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- ---------------
# absl-py                      2.1.0
# altair                       5.3.0
# annotated-types              0.7.0
# anyio                        4.3.0
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# async-lru                    2.0.4
# attrs                        23.2.0
# Babel                        2.14.0
# beautifulsoup4               4.12.3
# bleach                       6.1.0
# blinker                      1.8.2
# blis                         0.7.11
# cachetools                   5.3.3
# catalogue                    2.0.10
# certifi                      2024.2.2
# cffi                         1.16.0
# charset-normalizer           3.3.2
# click                        8.1.7
# cloudpathlib                 0.18.1
# colorama                     0.4.6
# ...

# %%
import streamlit as st
from ModelClasses import *  # Ensure you have your model classes available in this module
from huggingface_hub import hf_hub_download
import pickle
import csv
from streamlit import radio  # This is actually not necessary; you can use st.radio directly

import torch
import numpy as np
import random
import re
from sentence_transformers import SentenceTransformer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import time
import gensim
from gensim.models.fasttext import load_facebook_model
# Out:
# C:\Users\Lesty\Documents\ITB\SemanticSearch\env\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
# Print the versions of each library
print("Streamlit version:", st.__version__)
print("Pickle module version: Standard library module, no version attribute")
print("CSV module version: Standard library module, no version attribute")
print("Torch version:", torch.__version__)
print("NumPy version:", np.__version__)
print("Random module version: Standard library module, no version attribute")
print("Re module version: Standard library module, no version attribute")
# print("SentenceTransformer version:", SentenceTransformer.__version__)
# print("NLTK version:", nltk.__version__)  # NLTK version can be retrieved from any submodule
print("Gensim version:", gensim.__version__)
# Out:
# Streamlit version: 1.36.0
# Pickle module version: Standard library module, no version attribute
# CSV module version: Standard library module, no version attribute
# Torch version: 2.2.1+cu121
# NumPy version: 1.26.3
# Random module version: Standard library module, no version attribute
# Re module version: Standard library module, no version attribute
# Gensim version: 4.3.2

# %%
huggingface-hub              0.20.3
sentence-transformers        3.0.1
regex                        2023.12.25
nltk                         3.8.1
